# %% [markdown]
# <a href="https://colab.research.google.com/github/mikhael-cutajar/ARI5903---Research-Topics-in-Computer-Vision/blob/main/Visualise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd 
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Computer_vision_Assignment/accuracy_over_epochs.csv', index_col=0)

plot = df.plot(ylim = [0,1], figsize=(20,10))
plot.set_xlabel("Epoch")
plot.set_ylabel("IoU Score")
# Out:
# Text(0, 0.5, 'IoU Score')

# %%
import pandas as pd 

df2 = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Computer_vision_Assignment/accuracy_over_epochs_valid.csv', index_col=0)

plot = df2.plot(ylim = [0,1], figsize=(20,10))
plot.set_xlabel("Epoch")
plot.set_ylabel("IoU Score")


df2.to_csv('/content/gdrive/MyDrive/Colab Notebooks/Computer_vision_Assignment/accuracy_over_epochs_valid.csv')
